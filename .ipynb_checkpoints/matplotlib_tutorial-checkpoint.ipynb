# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
import numpy as np 
import pandas as pd 

# %reload_ext autoreload 
# %autoreload 2

# %% [markdown]
# ## Functional Plot

# %%
x_1 = np.linspace(0, 5, 10)
y_1 = x_1**2
plt.plot(x_1, y_1)
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
# if you're not using jupyter notebook, to show -> plt.show()
# Out:
# Text(0, 0.5, 'Days Squared')

# %% [markdown]
# ## Print Multiple Plots

# %%
plt.subplot(1, 2, 1)
plt.plot(x_1, y_1, 'r')
plt.subplot(1, 2, 2)
plt.plot(x_1, y_1, 'g')

# %% [markdown]
# ## Using Figure Objects

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1,y_1,label='x/x^2')
axes_1.plot(y_1,x_1,label='x^2/x')

axes_1.legend(loc=0)
# upper right: 1, upper left: 2, lower left: 3, lower right: 4,
# or supply a tuple of x & y from lower left 

axes_2 = fig_1.add_axes([0.45, 0.45, 0.4, 0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1,y_1,'r', label='axes_2')
axes_2.legend(loc=0)

axes_2.text(0, 35, 'Message')
# Out:
# Text(0, 35, 'Message')

# %% [markdown]
# ## Subplots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout()
axes_2[1].set_title('Plot 2')
axes_2[1].set_xlabel('X')
axes_2[1].set_ylabel('X squared')
axes_2[1].plot(x_1,y_1)

# %% [markdown]
# ## Appearance Options

# %%
# Default colors(b: blue, g: green, r: red, c: cyan, m: magenta, y: yellow,
# k: black, w: white)
# color="0.75" creates 75% gray
# You can use hexcodes -> color='#eeefff'
# You can use color names found next like this color="burlywood"
# https://en.wikipedia.org/wiki/Web_colors

# %% [markdown]
# ## Save Visual to a File
